# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, GlobalMaxPooling2D, BatchNormalization
from tensorflow.keras.applications import VGG16
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Model parameters
image_size = 224
input_shape = (image_size, image_size, 3)
epochs = 50
batch_size = 32

# Define the dataset path and categories
dataset_path = '/content/drive/My Drive/new_fol_vig'
categories = ['NE', 'DME', 'DR1', 'GL']

# Initialize an empty list to store labels
labels = []

# Iterate through the directories in the dataset path
for category in categories:
    category_path = os.path.join(dataset_path, category)
    # Check if the directory exists and is indeed a directory
    if os.path.isdir(category_path):
        # List all files in the category directory
        file_names = os.listdir(category_path)
        # Iterate through each file in the directory
        for file_name in file_names:
            # Construct the full file path
            file_path = os.path.join(category_path, file_name)
            # Append the filename and category to the labels list
            labels.append((file_path, category))

# Create a DataFrame from the labels list
df = pd.DataFrame(data=labels, columns=['filename', 'category'])

# Encode the 'category' column
encoder = LabelEncoder()
df['category'] = encoder.fit_transform(df['category'])
print(df.head())
df = df.sample(frac=1).reset_index(drop=True)
# Out:
# Mounted at /content/drive
#                                             filename  category
# 0  /content/drive/My Drive/new_fol_vig/NE/NL_001.png         3
# 1  /content/drive/My Drive/new_fol_vig/NE/NL_004.png         3
# 2  /content/drive/My Drive/new_fol_vig/NE/NL_005.png         3
# 3  /content/drive/My Drive/new_fol_vig/NE/NL_006.png         3
# 4  /content/drive/My Drive/new_fol_vig/NE/NL_002.png         3

# %%
train_df, validate_df = train_test_split(df, test_size=0.2)

# Load images and labels from DataFrame
X_train = np.array([img_to_array(load_img(img_path, target_size=(image_size, image_size))) for img_path in train_df['filename']])
y_train = np.array(train_df['category'])
X_validate = np.array([img_to_array(load_img(img_path, target_size=(image_size, image_size))) for img_path in validate_df['filename']])
y_validate = np.array(validate_df['category'])

# Normalize pixel values to the range [0, 1]
X_train = X_train / 255.0
X_validate = X_validate / 255.0



# Split the DataFrame into train and validation sets
train_df, validate_df = train_test_split(df, test_size=0.2)

# Load images and labels from DataFrame
X_train = np.array([img_to_array(load_img(img_path, target_size=(image_size, image_size))) for img_path in train_df['filename']])
y_train = np.array(train_df['category'])
X_validate = np.array([img_to_array(load_img(img_path, target_size=(image_size, image_size))) for img_path in validate_df['filename']])
y_validate = np.array(validate_df['category'])

# Normalize pixel values to the range [0, 1]
X_train = X_train / 255.0
X_validate = X_validate / 255.0

# %%
from tensorflow.keras.layers import Dense, GlobalMaxPooling2D, BatchNormalization, Dropout
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras import optimizers
# Define the model
pre_trained_model = DenseNet121(input_shape=input_shape, include_top=False, weights="imagenet")
for layer in pre_trained_model.layers[:120]:
    layer.trainable = False
for layer in pre_trained_model.layers[120:]:
    layer.trainable = True
last_layer = pre_trained_model.get_layer('relu')
last_output = last_layer.output
x = GlobalMaxPooling2D()(last_output)

x = BatchNormalization()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(len(categories), activation='softmax')(x)  # Change activation to softmax and number of neurons to num_classes
model = Model(pre_trained_model.input, x)

# Compile the model
model.compile(loss='sparse_categorical_crossentropy',  # Change loss function to sparse categorical cross-entropy
              optimizer=optimizers.Adam(lr=3e-4),  # Change optimizer to Adam and learning rate to 3e-4
              metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=epochs, batch_size=batch_size) #, callbacks=[early_stopping]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 11/11 [==============================] - 75s 1s/step - loss: 0.8073 - accuracy: 0.6909 - val_loss: 3.7204 - val_accuracy: 0.3614
# Epoch 2/50
# 11/11 [==============================] - 2s 203ms/step - loss: 0.2939 - accuracy: 0.8788 - val_loss: 9.8352 - val_accuracy: 0.5060
# Epoch 3/50
# 11/11 [==============================] - 2s 194ms/step - loss: 0.2636 - accuracy: 0.9000 - val_loss: 0.6754 - val_accuracy: 0.7711
# Epoch 4/50
# 11/11 [==============================] - 2s 203ms/step - loss: 0.2194 - accuracy: 0.9273 - val_loss: 121.3422 - val_accuracy: 0.2771
# Epoch 5/50
# 11/11 [==============================] - 2s 195ms/step - loss: 0.1509 - accuracy: 0.9485 - val_loss: 146.6754 - val_accuracy: 0.2771
# Epoch 6/50
# 11/11 [==============================] - 2s 216ms/step - loss: 0.0812 - accuracy: 0.9606 - val_loss: 133.3063 - val_accuracy: 0.2771
# Epoch 7/50
# 11/11 [==============================] - 2s 203ms/step - loss: 0.1225 - accuracy: 0.9606 - val_loss: 84.9366 - val_accuracy: 0.2771
# Epoch 8/50
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0561 - accuracy: 0.9818 - val_loss: 38.5159 - val_accuracy: 0.2771
# Epoch 9/50
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0204 - accuracy: 0.9939 - val_loss: 11.2746 - val_accuracy: 0.3012
# Epoch 10/50
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0345 - accuracy: 0.9848 - val_loss: 16.2189 - val_accuracy: 0.2771
# Epoch 11/50
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0172 - accuracy: 0.9939 - val_loss: 17.8449 - val_accuracy: 0.2771
# Epoch 12/50
# 11/11 [==============================] - 2s 219ms/step - loss: 0.1607 - accuracy: 0.9576 - val_loss: 31.0887 - val_accuracy: 0.2771
# Epoch 13/50
# 11/11 [==============================] - 2s 214ms/step - loss: 0.0880 - accuracy: 0.9606 - val_loss: 30.8535 - val_accuracy: 0.2771
# Epoch 14/50
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0775 - accuracy: 0.9667 - val_loss: 30.5395 - val_accuracy: 0.2771
# Epoch 15/50
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0376 - accuracy: 0.9909 - val_loss: 31.9835 - val_accuracy: 0.2771
# Epoch 16/50
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0919 - accuracy: 0.9697 - val_loss: 40.8945 - val_accuracy: 0.2771
# Epoch 17/50
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0136 - accuracy: 0.9939 - val_loss: 38.5172 - val_accuracy: 0.2771
# Epoch 18/50
# 11/11 [==============================] - 2s 220ms/step - loss: 0.0509 - accuracy: 0.9818 - val_loss: 30.4918 - val_accuracy: 0.2771
# Epoch 19/50
# 11/11 [==============================] - 2s 212ms/step - loss: 0.0061 - accuracy: 0.9970 - val_loss: 24.9181 - val_accuracy: 0.2771
# Epoch 20/50
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 19.5078 - val_accuracy: 0.2771
# Epoch 21/50
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0166 - accuracy: 0.9909 - val_loss: 6.5625 - val_accuracy: 0.3855
# Epoch 22/50
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 7.3287 - val_accuracy: 0.5663
# Epoch 23/50
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 7.0595 - val_accuracy: 0.5663
# Epoch 24/50
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 5.3857 - val_accuracy: 0.5663
# Epoch 25/50
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.3538 - val_accuracy: 0.5663
# Epoch 26/50
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.3288 - val_accuracy: 0.6265
# Epoch 27/50
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0070 - accuracy: 0.9970 - val_loss: 0.3616 - val_accuracy: 0.9036
# Epoch 28/50
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0853 - accuracy: 0.9667 - val_loss: 0.3678 - val_accuracy: 0.9157
# Epoch 29/50
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0693 - accuracy: 0.9848 - val_loss: 10.1581 - val_accuracy: 0.3735
# Epoch 30/50
# 11/11 [==============================] - 2s 222ms/step - loss: 0.0626 - accuracy: 0.9848 - val_loss: 2.1998 - val_accuracy: 0.7349
# Epoch 31/50
# 11/11 [==============================] - 2s 214ms/step - loss: 0.1729 - accuracy: 0.9545 - val_loss: 2.0834 - val_accuracy: 0.7108
# Epoch 32/50
# 11/11 [==============================] - 2s 208ms/step - loss: 0.1840 - accuracy: 0.9485 - val_loss: 0.9907 - val_accuracy: 0.8313
# Epoch 33/50
# 11/11 [==============================] - 2s 198ms/step - loss: 0.0353 - accuracy: 0.9879 - val_loss: 21.0193 - val_accuracy: 0.3494
# Epoch 34/50
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0516 - accuracy: 0.9879 - val_loss: 111.1941 - val_accuracy: 0.2771
# Epoch 35/50
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0255 - accuracy: 0.9909 - val_loss: 113.0342 - val_accuracy: 0.2771
# Epoch 36/50
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0168 - accuracy: 0.9939 - val_loss: 86.0727 - val_accuracy: 0.2771
# Epoch 37/50
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0242 - accuracy: 0.9939 - val_loss: 55.7351 - val_accuracy: 0.2771
# Epoch 38/50
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0398 - accuracy: 0.9909 - val_loss: 44.3780 - val_accuracy: 0.2771
# Epoch 39/50
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0463 - accuracy: 0.9879 - val_loss: 44.2912 - val_accuracy: 0.2771
# Epoch 40/50
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0251 - accuracy: 0.9939 - val_loss: 31.0841 - val_accuracy: 0.2892
# Epoch 41/50
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0297 - accuracy: 0.9848 - val_loss: 39.4341 - val_accuracy: 0.2771
# Epoch 42/50
# 11/11 [==============================] - 2s 218ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 40.6187 - val_accuracy: 0.2771
# Epoch 43/50
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0707 - accuracy: 0.9818 - val_loss: 4.3944 - val_accuracy: 0.6386
# Epoch 44/50
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 1.8210 - val_accuracy: 0.7831
# Epoch 45/50
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0209 - accuracy: 0.9939 - val_loss: 10.5306 - val_accuracy: 0.3373
# Epoch 46/50
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0335 - accuracy: 0.9909 - val_loss: 8.8926 - val_accuracy: 0.4940
# Epoch 47/50
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0113 - accuracy: 0.9939 - val_loss: 4.4566 - val_accuracy: 0.5783
# Epoch 48/50
# 11/11 [==============================] - 2s 220ms/step - loss: 6.7452e-04 - accuracy: 1.0000 - val_loss: 1.6244 - val_accuracy: 0.7711
# Epoch 49/50
# 11/11 [==============================] - 2s 214ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.2121 - val_accuracy: 0.8675
# Epoch 50/50
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0241 - accuracy: 0.9939 - val_loss: 1.0120 - val_accuracy: 0.9277

# %%
# Make predictions
y_pred = np.argmax(model.predict(X_validate), axis=-1)

# Generate classification report
print("Classification Report:")
print(classification_report(y_validate, y_pred, target_names=categories))

# Generate confusion matrix
cm = confusion_matrix(y_validate, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 3/3 [==============================] - 2s 113ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#           NE       1.00      1.00      1.00        23
#          DME       1.00      1.00      1.00        24
#          DR1       0.75      1.00      0.86        18
#           GL       1.00      0.67      0.80        18
#
#     accuracy                           0.93        83
#    macro avg       0.94      0.92      0.91        83
# weighted avg       0.95      0.93      0.93        83

# %%
drive.mount('/content/drive')

# Model parameters
image_size = 224
input_shape = (image_size, image_size, 3)
epochs = 50
batch_size = 32

# Define the dataset path and categories
dataset_path = '/content/drive/My Drive/new_fol_vig'
categories = ['NE', 'DME']

labels = []

for category in categories:
    category_path = os.path.join(dataset_path, category)
    if os.path.isdir(category_path):
        file_names = os.listdir(category_path)
        for file_name in file_names:
            file_path = os.path.join(category_path, file_name)
            labels.append((file_path, category))

# Create a DataFrame from the labels list
df = pd.DataFrame(data=labels, columns=['filename', 'category'])

# Encode the 'category' column
encoder = LabelEncoder()
df['category'] = encoder.fit_transform(df['category'])
print(df.head())
df = df.sample(frac=1).reset_index(drop=True)

# Split the DataFrame into train and validation sets
train_df, validate_df = train_test_split(df, test_size=0.2)

# Load images and labels from DataFrame
X_train = np.array([img_to_array(load_img(img_path, target_size=(image_size, image_size))) for img_path in train_df['filename']])
y_train = np.array(train_df['category'])
X_validate = np.array([img_to_array(load_img(img_path, target_size=(image_size, image_size))) for img_path in validate_df['filename']])
y_validate = np.array(validate_df['category'])

# Normalize pixel values to the range [0, 1]
X_train = X_train / 255.0
X_validate = X_validate / 255.0
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                                             filename  category
# 0  /content/drive/My Drive/new_fol_vig/NE/NL_001.png         1
# 1  /content/drive/My Drive/new_fol_vig/NE/NL_004.png         1
# 2  /content/drive/My Drive/new_fol_vig/NE/NL_005.png         1
# 3  /content/drive/My Drive/new_fol_vig/NE/NL_006.png         1
# 4  /content/drive/My Drive/new_fol_vig/NE/NL_002.png         1

# %%
from tensorflow.keras.layers import Dense, GlobalMaxPooling2D, BatchNormalization, Dropout
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras import optimizers
# Define the model
pre_trained_model = DenseNet121(input_shape=input_shape, include_top=False, weights="imagenet")
for layer in pre_trained_model.layers[:120]:
    layer.trainable = False
for layer in pre_trained_model.layers[120:]:
    layer.trainable = True
last_layer = pre_trained_model.get_layer('relu')
last_output = last_layer.output
x = GlobalMaxPooling2D()(last_output)

x = BatchNormalization()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(len(categories), activation='softmax')(x)
model = Model(pre_trained_model.input, x)

# Compile the model
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizers.Adam(lr=3e-4),
              metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=epochs, batch_size=batch_size) #, callbacks=[early_stopping]

y_pred = np.argmax(model.predict(X_validate), axis=-1)

# Generate classification report
print("Classification Report:")
print(classification_report(y_validate, y_pred, target_names=categories))

# Generate confusion matrix
cm = confusion_matrix(y_validate, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 5/5 [==============================] - 60s 4s/step - loss: 0.3768 - accuracy: 0.8322 - val_loss: 1.8446 - val_accuracy: 0.6053
# Epoch 2/50
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0380 - accuracy: 0.9732 - val_loss: 39.4281 - val_accuracy: 0.6053
# Epoch 3/50
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0375 - accuracy: 0.9866 - val_loss: 153.6590 - val_accuracy: 0.6053
# Epoch 4/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 297.2885 - val_accuracy: 0.6053
# Epoch 5/50
# 5/5 [==============================] - 1s 213ms/step - loss: 3.1167e-04 - accuracy: 1.0000 - val_loss: 369.8968 - val_accuracy: 0.6053
# Epoch 6/50
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 373.7671 - val_accuracy: 0.6053
# Epoch 7/50
# 5/5 [==============================] - 1s 228ms/step - loss: 5.9579e-05 - accuracy: 1.0000 - val_loss: 337.0608 - val_accuracy: 0.6053
# Epoch 8/50
# 5/5 [==============================] - 1s 236ms/step - loss: 7.5851e-05 - accuracy: 1.0000 - val_loss: 290.1179 - val_accuracy: 0.6053
# Epoch 9/50
# 5/5 [==============================] - 1s 231ms/step - loss: 7.7253e-05 - accuracy: 1.0000 - val_loss: 243.7178 - val_accuracy: 0.6053
# Epoch 10/50
# 5/5 [==============================] - 1s 208ms/step - loss: 1.6615e-05 - accuracy: 1.0000 - val_loss: 204.6085 - val_accuracy: 0.6053
# Epoch 11/50
# 5/5 [==============================] - 1s 213ms/step - loss: 6.4104e-05 - accuracy: 1.0000 - val_loss: 172.0202 - val_accuracy: 0.6053
# Epoch 12/50
# 5/5 [==============================] - 1s 207ms/step - loss: 1.4466e-04 - accuracy: 1.0000 - val_loss: 145.6992 - val_accuracy: 0.6053
# Epoch 13/50
# 5/5 [==============================] - 1s 206ms/step - loss: 1.0682e-05 - accuracy: 1.0000 - val_loss: 124.2842 - val_accuracy: 0.6053
# Epoch 14/50
# 5/5 [==============================] - 1s 214ms/step - loss: 3.9598e-04 - accuracy: 1.0000 - val_loss: 106.4252 - val_accuracy: 0.6053
# Epoch 15/50
# 5/5 [==============================] - 1s 212ms/step - loss: 3.0026e-06 - accuracy: 1.0000 - val_loss: 91.2018 - val_accuracy: 0.6053
# Epoch 16/50
# 5/5 [==============================] - 1s 212ms/step - loss: 4.3363e-06 - accuracy: 1.0000 - val_loss: 78.3431 - val_accuracy: 0.6053
# Epoch 17/50
# 5/5 [==============================] - 1s 212ms/step - loss: 6.6231e-06 - accuracy: 1.0000 - val_loss: 67.5950 - val_accuracy: 0.6053
# Epoch 18/50
# 5/5 [==============================] - 1s 214ms/step - loss: 5.8535e-05 - accuracy: 1.0000 - val_loss: 58.6656 - val_accuracy: 0.6053
# Epoch 19/50
# 5/5 [==============================] - 1s 213ms/step - loss: 2.6192e-06 - accuracy: 1.0000 - val_loss: 51.1692 - val_accuracy: 0.6053
# Epoch 20/50
# 5/5 [==============================] - 1s 239ms/step - loss: 2.1896e-04 - accuracy: 1.0000 - val_loss: 44.4805 - val_accuracy: 0.6053
# Epoch 21/50
# 5/5 [==============================] - 1s 227ms/step - loss: 1.4985e-06 - accuracy: 1.0000 - val_loss: 38.7712 - val_accuracy: 0.6053
# Epoch 22/50
# 5/5 [==============================] - 1s 235ms/step - loss: 7.3644e-05 - accuracy: 1.0000 - val_loss: 34.1019 - val_accuracy: 0.6053
# Epoch 23/50
# 5/5 [==============================] - 1s 206ms/step - loss: 4.2272e-06 - accuracy: 1.0000 - val_loss: 30.2105 - val_accuracy: 0.6053
# Epoch 24/50
# 5/5 [==============================] - 1s 215ms/step - loss: 1.3449e-06 - accuracy: 1.0000 - val_loss: 26.9017 - val_accuracy: 0.6053
# Epoch 25/50
# 5/5 [==============================] - 1s 214ms/step - loss: 1.1241e-06 - accuracy: 1.0000 - val_loss: 23.9147 - val_accuracy: 0.6053
# Epoch 26/50
# 5/5 [==============================] - 1s 206ms/step - loss: 1.8241e-06 - accuracy: 1.0000 - val_loss: 21.3275 - val_accuracy: 0.6053
# Epoch 27/50
# 5/5 [==============================] - 1s 206ms/step - loss: 8.4564e-07 - accuracy: 1.0000 - val_loss: 18.9752 - val_accuracy: 0.6053
# Epoch 28/50
# 5/5 [==============================] - 1s 212ms/step - loss: 3.7527e-04 - accuracy: 1.0000 - val_loss: 16.9560 - val_accuracy: 0.6053
# Epoch 29/50
# 5/5 [==============================] - 1s 213ms/step - loss: 2.1569e-06 - accuracy: 1.0000 - val_loss: 15.0213 - val_accuracy: 0.6053
# Epoch 30/50
# 5/5 [==============================] - 1s 213ms/step - loss: 2.0320e-05 - accuracy: 1.0000 - val_loss: 13.1609 - val_accuracy: 0.6053
# Epoch 31/50
# 5/5 [==============================] - 1s 213ms/step - loss: 9.2289e-06 - accuracy: 1.0000 - val_loss: 11.4672 - val_accuracy: 0.6053
# Epoch 32/50
# 5/5 [==============================] - 1s 220ms/step - loss: 1.1664e-04 - accuracy: 1.0000 - val_loss: 10.4802 - val_accuracy: 0.6053
# Epoch 33/50
# 5/5 [==============================] - 1s 229ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 10.3923 - val_accuracy: 0.6053
# Epoch 34/50
# 5/5 [==============================] - 1s 226ms/step - loss: 9.0246e-07 - accuracy: 1.0000 - val_loss: 10.1662 - val_accuracy: 0.6053
# Epoch 35/50
# 5/5 [==============================] - 1s 219ms/step - loss: 4.9656e-05 - accuracy: 1.0000 - val_loss: 9.5317 - val_accuracy: 0.6053
# Epoch 36/50
# 5/5 [==============================] - 1s 211ms/step - loss: 2.1537e-05 - accuracy: 1.0000 - val_loss: 8.6715 - val_accuracy: 0.6053
# Epoch 37/50
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.7381 - val_accuracy: 0.6053
# Epoch 38/50
# 5/5 [==============================] - 1s 216ms/step - loss: 1.5655e-05 - accuracy: 1.0000 - val_loss: 4.1733 - val_accuracy: 0.6316
# Epoch 39/50
# 5/5 [==============================] - 1s 207ms/step - loss: 4.1472e-05 - accuracy: 1.0000 - val_loss: 2.5112 - val_accuracy: 0.6842
# Epoch 40/50
# 5/5 [==============================] - 1s 214ms/step - loss: 6.1254e-06 - accuracy: 1.0000 - val_loss: 1.5010 - val_accuracy: 0.7632
# Epoch 41/50
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0219 - accuracy: 0.9933 - val_loss: 11.8360 - val_accuracy: 0.6053
# Epoch 42/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0239 - accuracy: 0.9933 - val_loss: 34.1054 - val_accuracy: 0.6053
# Epoch 43/50
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0179 - accuracy: 0.9933 - val_loss: 35.7164 - val_accuracy: 0.6053
# Epoch 44/50
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0786 - accuracy: 0.9799 - val_loss: 18.8335 - val_accuracy: 0.6053
# Epoch 45/50
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0450 - accuracy: 0.9933 - val_loss: 45.7506 - val_accuracy: 0.6053
# Epoch 46/50
# 5/5 [==============================] - 1s 219ms/step - loss: 1.1080e-04 - accuracy: 1.0000 - val_loss: 77.7020 - val_accuracy: 0.6053
# Epoch 47/50
# 5/5 [==============================] - 1s 232ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 50.1380 - val_accuracy: 0.6053
# Epoch 48/50
# 5/5 [==============================] - 1s 223ms/step - loss: 8.0512e-05 - accuracy: 1.0000 - val_loss: 2.8181 - val_accuracy: 0.7632
# Epoch 49/50
# 5/5 [==============================] - 1s 209ms/step - loss: 2.9621e-04 - accuracy: 1.0000 - val_loss: 17.7762 - val_accuracy: 0.4737
# Epoch 50/50
# 5/5 [==============================] - 1s 204ms/step - loss: 5.0288e-06 - accuracy: 1.0000 - val_loss: 7.3186 - val_accuracy: 0.7368
# 2/2 [==============================] - 2s 121ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#           NE       1.00      0.57      0.72        23
#          DME       0.60      1.00      0.75        15
#
#     accuracy                           0.74        38
#    macro avg       0.80      0.78      0.74        38
# weighted avg       0.84      0.74      0.73        38

# %%
drive.mount('/content/drive')

# Model parameters
image_size = 224
input_shape = (image_size, image_size, 3)
epochs = 50
batch_size = 32

# Define the dataset path and categories
dataset_path = '/content/drive/My Drive/new_fol_vig'
categories = ['NE', 'DR1']

# Initialize an empty list to store labels
labels = []

# Iterate through the directories in the dataset path
for category in categories:
    category_path = os.path.join(dataset_path, category)
    # Check if the directory exists and is indeed a directory
    if os.path.isdir(category_path):
        # List all files in the category directory
        file_names = os.listdir(category_path)
        # Iterate through each file in the directory
        for file_name in file_names:
            # Construct the full file path
            file_path = os.path.join(category_path, file_name)
            # Append the filename and category to the labels list
            labels.append((file_path, category))

# Create a DataFrame from the labels list
df = pd.DataFrame(data=labels, columns=['filename', 'category'])

# Encode the 'category' column
encoder = LabelEncoder()
df['category'] = encoder.fit_transform(df['category'])
print(df.head())
df = df.sample(frac=1).reset_index(drop=True)

# Split the DataFrame into train and validation sets
train_df, validate_df = train_test_split(df, test_size=0.2)

# Load images and labels from DataFrame
X_train = np.array([img_to_array(load_img(img_path, target_size=(image_size, image_size))) for img_path in train_df['filename']])
y_train = np.array(train_df['category'])
X_validate = np.array([img_to_array(load_img(img_path, target_size=(image_size, image_size))) for img_path in validate_df['filename']])
y_validate = np.array(validate_df['category'])

# Normalize pixel values to the range [0, 1]
X_train = X_train / 255.0
X_validate = X_validate / 255.0
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                                             filename  category
# 0  /content/drive/My Drive/new_fol_vig/NE/NL_001.png         1
# 1  /content/drive/My Drive/new_fol_vig/NE/NL_004.png         1
# 2  /content/drive/My Drive/new_fol_vig/NE/NL_005.png         1
# 3  /content/drive/My Drive/new_fol_vig/NE/NL_006.png         1
# 4  /content/drive/My Drive/new_fol_vig/NE/NL_002.png         1

# %%
from tensorflow.keras.layers import Dense, GlobalMaxPooling2D, BatchNormalization, Dropout
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras import optimizers
# Define the model
pre_trained_model = DenseNet121(input_shape=input_shape, include_top=False, weights="imagenet")
for layer in pre_trained_model.layers[:120]:
    layer.trainable = False
for layer in pre_trained_model.layers[120:]:
    layer.trainable = True
last_layer = pre_trained_model.get_layer('relu')
last_output = last_layer.output
x = GlobalMaxPooling2D()(last_output)

x = BatchNormalization()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(len(categories), activation='softmax')(x)  # Change activation to softmax and number of neurons to num_classes
model = Model(pre_trained_model.input, x)

# Compile the model
model.compile(loss='sparse_categorical_crossentropy',  # Change loss function to sparse categorical cross-entropy
              optimizer=optimizers.Adam(lr=3e-4),  # Change optimizer to Adam and learning rate to 3e-4
              metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=epochs, batch_size=batch_size) #, callbacks=[early_stopping]

y_pred = np.argmax(model.predict(X_validate), axis=-1)

# Generate classification report
print("Classification Report:")
print(classification_report(y_validate, y_pred, target_names=categories))

# Generate confusion matrix
cm = confusion_matrix(y_validate, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 6/6 [==============================] - 58s 3s/step - loss: 0.2587 - accuracy: 0.9023 - val_loss: 0.8910 - val_accuracy: 0.5682
# Epoch 2/50
# 6/6 [==============================] - 1s 200ms/step - loss: 2.3598e-04 - accuracy: 1.0000 - val_loss: 1.6962 - val_accuracy: 0.4773
# Epoch 3/50
# 6/6 [==============================] - 1s 201ms/step - loss: 1.5134e-04 - accuracy: 1.0000 - val_loss: 1.4896 - val_accuracy: 0.4773
# Epoch 4/50
# 6/6 [==============================] - 1s 209ms/step - loss: 1.0539e-05 - accuracy: 1.0000 - val_loss: 0.8389 - val_accuracy: 0.5227
# Epoch 5/50
# 6/6 [==============================] - 1s 220ms/step - loss: 4.5115e-05 - accuracy: 1.0000 - val_loss: 0.2252 - val_accuracy: 0.9091
# Epoch 6/50
# 6/6 [==============================] - 1s 220ms/step - loss: 1.6470e-05 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 1.0000
# Epoch 7/50
# 6/6 [==============================] - 1s 205ms/step - loss: 6.7354e-06 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 8/50
# 6/6 [==============================] - 1s 202ms/step - loss: 3.3407e-05 - accuracy: 1.0000 - val_loss: 3.5412e-04 - val_accuracy: 1.0000
# Epoch 9/50
# 6/6 [==============================] - 1s 203ms/step - loss: 2.6621e-06 - accuracy: 1.0000 - val_loss: 8.3789e-05 - val_accuracy: 1.0000
# Epoch 10/50
# 6/6 [==============================] - 1s 201ms/step - loss: 2.0017e-06 - accuracy: 1.0000 - val_loss: 3.0047e-05 - val_accuracy: 1.0000
# Epoch 11/50
# 6/6 [==============================] - 1s 200ms/step - loss: 2.0896e-07 - accuracy: 1.0000 - val_loss: 1.0801e-05 - val_accuracy: 1.0000
# Epoch 12/50
# 6/6 [==============================] - 1s 200ms/step - loss: 4.1107e-09 - accuracy: 1.0000 - val_loss: 4.9253e-06 - val_accuracy: 1.0000
# Epoch 13/50
# 6/6 [==============================] - 1s 200ms/step - loss: 5.4199e-05 - accuracy: 1.0000 - val_loss: 1.5145e-06 - val_accuracy: 1.0000
# Epoch 14/50
# 6/6 [==============================] - 1s 203ms/step - loss: 1.4250e-07 - accuracy: 1.0000 - val_loss: 1.9507e-07 - val_accuracy: 1.0000
# Epoch 15/50
# 6/6 [==============================] - 1s 204ms/step - loss: 1.2962e-06 - accuracy: 1.0000 - val_loss: 9.2116e-08 - val_accuracy: 1.0000
# Epoch 16/50
# 6/6 [==============================] - 1s 219ms/step - loss: 5.9605e-08 - accuracy: 1.0000 - val_loss: 6.2314e-08 - val_accuracy: 1.0000
# Epoch 17/50
# 6/6 [==============================] - 1s 217ms/step - loss: 7.8788e-08 - accuracy: 1.0000 - val_loss: 3.7930e-08 - val_accuracy: 1.0000
# Epoch 18/50
# 6/6 [==============================] - 1s 211ms/step - loss: 1.7421e-06 - accuracy: 1.0000 - val_loss: 3.2512e-08 - val_accuracy: 1.0000
# Epoch 19/50
# 6/6 [==============================] - 1s 202ms/step - loss: 6.0492e-05 - accuracy: 1.0000 - val_loss: 1.0837e-08 - val_accuracy: 1.0000
# Epoch 20/50
# 6/6 [==============================] - 1s 203ms/step - loss: 1.5517e-06 - accuracy: 1.0000 - val_loss: 5.4186e-09 - val_accuracy: 1.0000
# Epoch 21/50
# 6/6 [==============================] - 1s 199ms/step - loss: 1.0962e-08 - accuracy: 1.0000 - val_loss: 8.1279e-09 - val_accuracy: 1.0000
# Epoch 22/50
# 6/6 [==============================] - 1s 203ms/step - loss: 2.0621e-07 - accuracy: 1.0000 - val_loss: 8.1279e-09 - val_accuracy: 1.0000
# Epoch 23/50
# 6/6 [==============================] - 1s 199ms/step - loss: 5.4809e-08 - accuracy: 1.0000 - val_loss: 8.1279e-09 - val_accuracy: 1.0000
# Epoch 24/50
# 6/6 [==============================] - 1s 200ms/step - loss: 2.0690e-07 - accuracy: 1.0000 - val_loss: 8.1279e-09 - val_accuracy: 1.0000
# Epoch 25/50
# 6/6 [==============================] - 1s 199ms/step - loss: 1.4319e-07 - accuracy: 1.0000 - val_loss: 8.1279e-09 - val_accuracy: 1.0000
# Epoch 26/50
# 6/6 [==============================] - 1s 202ms/step - loss: 6.9881e-08 - accuracy: 1.0000 - val_loss: 8.1279e-09 - val_accuracy: 1.0000
# Epoch 27/50
# 6/6 [==============================] - 1s 217ms/step - loss: 4.7958e-09 - accuracy: 1.0000 - val_loss: 8.1279e-09 - val_accuracy: 1.0000
# Epoch 28/50
# 6/6 [==============================] - 1s 223ms/step - loss: 3.6311e-08 - accuracy: 1.0000 - val_loss: 8.1279e-09 - val_accuracy: 1.0000
# Epoch 29/50
# 6/6 [==============================] - 1s 211ms/step - loss: 6.7826e-08 - accuracy: 1.0000 - val_loss: 5.4186e-09 - val_accuracy: 1.0000
# Epoch 30/50
# 6/6 [==============================] - 1s 201ms/step - loss: 1.7265e-07 - accuracy: 1.0000 - val_loss: 5.4186e-09 - val_accuracy: 1.0000
# Epoch 31/50
# 6/6 [==============================] - 1s 203ms/step - loss: 5.6864e-08 - accuracy: 1.0000 - val_loss: 5.4186e-09 - val_accuracy: 1.0000
# Epoch 32/50
# 6/6 [==============================] - 1s 202ms/step - loss: 1.2332e-07 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 33/50
# 6/6 [==============================] - 1s 201ms/step - loss: 2.1101e-07 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 34/50
# 6/6 [==============================] - 1s 198ms/step - loss: 6.2345e-08 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 35/50
# 6/6 [==============================] - 1s 198ms/step - loss: 3.4256e-09 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 36/50
# 6/6 [==============================] - 1s 202ms/step - loss: 1.8498e-08 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 37/50
# 6/6 [==============================] - 1s 199ms/step - loss: 6.0426e-07 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 38/50
# 6/6 [==============================] - 1s 223ms/step - loss: 9.5640e-07 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 39/50
# 6/6 [==============================] - 1s 222ms/step - loss: 4.4394e-07 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 40/50
# 6/6 [==============================] - 1s 219ms/step - loss: 2.1649e-07 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 41/50
# 6/6 [==============================] - 1s 199ms/step - loss: 1.9389e-07 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 42/50
# 6/6 [==============================] - 1s 202ms/step - loss: 5.4809e-09 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 43/50
# 6/6 [==============================] - 1s 201ms/step - loss: 1.6922e-07 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 44/50
# 6/6 [==============================] - 1s 199ms/step - loss: 2.0279e-07 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 45/50
# 6/6 [==============================] - 1s 204ms/step - loss: 4.9738e-07 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 46/50
# 6/6 [==============================] - 1s 206ms/step - loss: 1.4387e-08 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 47/50
# 6/6 [==============================] - 1s 201ms/step - loss: 9.7971e-08 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 48/50
# 6/6 [==============================] - 1s 200ms/step - loss: 8.6683e-06 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 49/50
# 6/6 [==============================] - 1s 220ms/step - loss: 2.3294e-08 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# Epoch 50/50
# 6/6 [==============================] - 1s 221ms/step - loss: 6.1660e-09 - accuracy: 1.0000 - val_loss: 2.7093e-09 - val_accuracy: 1.0000
# 2/2 [==============================] - 3s 117ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#           NE       1.00      1.00      1.00        23
#          DR1       1.00      1.00      1.00        21
#
#     accuracy                           1.00        44
#    macro avg       1.00      1.00      1.00        44
# weighted avg       1.00      1.00      1.00        44

# %%
drive.mount('/content/drive')

# Model parameters
image_size = 224
input_shape = (image_size, image_size, 3)
epochs = 50
batch_size = 32

# Define the dataset path and categories
dataset_path = '/content/drive/My Drive/new_fol_vig'
categories = ['NE', 'GL']

# Initialize an empty list to store labels
labels = []

for category in categories:
    category_path = os.path.join(dataset_path, category)
    if os.path.isdir(category_path):
        file_names = os.listdir(category_path)
        for file_name in file_names:
            file_path = os.path.join(category_path, file_name)
            labels.append((file_path, category))

# Create a DataFrame from the labels list
df = pd.DataFrame(data=labels, columns=['filename', 'category'])

# Encode the 'category' column
encoder = LabelEncoder()
df['category'] = encoder.fit_transform(df['category'])
print(df.head())
df = df.sample(frac=1).reset_index(drop=True)

# Split the DataFrame into train and validation sets
train_df, validate_df = train_test_split(df, test_size=0.2)

# Load images and labels from DataFrame
X_train = np.array([img_to_array(load_img(img_path, target_size=(image_size, image_size))) for img_path in train_df['filename']])
y_train = np.array(train_df['category'])
X_validate = np.array([img_to_array(load_img(img_path, target_size=(image_size, image_size))) for img_path in validate_df['filename']])
y_validate = np.array(validate_df['category'])

# Normalize pixel values to the range [0, 1]
X_train = X_train / 255.0
X_validate = X_validate / 255.0
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                                             filename  category
# 0  /content/drive/My Drive/new_fol_vig/NE/NL_001.png         1
# 1  /content/drive/My Drive/new_fol_vig/NE/NL_004.png         1
# 2  /content/drive/My Drive/new_fol_vig/NE/NL_005.png         1
# 3  /content/drive/My Drive/new_fol_vig/NE/NL_006.png         1
# 4  /content/drive/My Drive/new_fol_vig/NE/NL_002.png         1

# %%
from tensorflow.keras.layers import Dense, GlobalMaxPooling2D, BatchNormalization, Dropout
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras import optimizers
# Define the model
pre_trained_model = DenseNet121(input_shape=input_shape, include_top=False, weights="imagenet")
for layer in pre_trained_model.layers[:120]:
    layer.trainable = False
for layer in pre_trained_model.layers[120:]:
    layer.trainable = True
last_layer = pre_trained_model.get_layer('relu')
last_output = last_layer.output
x = GlobalMaxPooling2D()(last_output)

x = BatchNormalization()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(len(categories), activation='softmax')(x)  # Change activation to softmax and number of neurons to num_classes
model = Model(pre_trained_model.input, x)

# Compile the model
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizers.Adam(lr=3e-4),
              metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=epochs, batch_size=batch_size) #, callbacks=[early_stopping]

y_pred = np.argmax(model.predict(X_validate), axis=-1)

# Generate classification report
print("Classification Report:")
print(classification_report(y_validate, y_pred, target_names=categories))

# Generate confusion matrix
cm = confusion_matrix(y_validate, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 5/5 [==============================] - 57s 3s/step - loss: 0.9289 - accuracy: 0.5290 - val_loss: 6.9897 - val_accuracy: 0.5385
# Epoch 2/50
# 5/5 [==============================] - 1s 216ms/step - loss: 0.4593 - accuracy: 0.8452 - val_loss: 8.7161 - val_accuracy: 0.5385
# Epoch 3/50
# 5/5 [==============================] - 1s 222ms/step - loss: 0.3060 - accuracy: 0.8774 - val_loss: 1.9918 - val_accuracy: 0.5385
# Epoch 4/50
# 5/5 [==============================] - 1s 216ms/step - loss: 0.2753 - accuracy: 0.8839 - val_loss: 6.0736 - val_accuracy: 0.4615
# Epoch 5/50
# 5/5 [==============================] - 1s 223ms/step - loss: 0.1532 - accuracy: 0.9484 - val_loss: 6.6403 - val_accuracy: 0.4615
# Epoch 6/50
# 5/5 [==============================] - 1s 221ms/step - loss: 0.1726 - accuracy: 0.9548 - val_loss: 0.9310 - val_accuracy: 0.7949
# Epoch 7/50
# 5/5 [==============================] - 1s 224ms/step - loss: 0.1240 - accuracy: 0.9677 - val_loss: 11.9357 - val_accuracy: 0.5385
# Epoch 8/50
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0285 - accuracy: 0.9871 - val_loss: 19.7506 - val_accuracy: 0.5385
# Epoch 9/50
# 5/5 [==============================] - 1s 239ms/step - loss: 0.0566 - accuracy: 0.9806 - val_loss: 18.6271 - val_accuracy: 0.5385
# Epoch 10/50
# 5/5 [==============================] - 1s 235ms/step - loss: 0.0251 - accuracy: 0.9871 - val_loss: 11.9005 - val_accuracy: 0.5385
# Epoch 11/50
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 7.1433 - val_accuracy: 0.5385
# Epoch 12/50
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0397 - accuracy: 0.9871 - val_loss: 1.3060 - val_accuracy: 0.8718
# Epoch 13/50
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0086 - accuracy: 0.9935 - val_loss: 3.0438 - val_accuracy: 0.6154
# Epoch 14/50
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 4.5264 - val_accuracy: 0.5641
# Epoch 15/50
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0153 - accuracy: 0.9935 - val_loss: 4.3742 - val_accuracy: 0.5641
# Epoch 16/50
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.8019 - val_accuracy: 0.7436
# Epoch 17/50
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0533 - accuracy: 0.9677 - val_loss: 1.9143 - val_accuracy: 0.8462
# Epoch 18/50
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 3.9630 - val_accuracy: 0.6923
# Epoch 19/50
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0687 - accuracy: 0.9806 - val_loss: 1.1569 - val_accuracy: 0.8462
# Epoch 20/50
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0852 - accuracy: 0.9742 - val_loss: 4.0443 - val_accuracy: 0.6667
# Epoch 21/50
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0509 - accuracy: 0.9806 - val_loss: 6.0611 - val_accuracy: 0.5897
# Epoch 22/50
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0186 - accuracy: 0.9935 - val_loss: 5.1549 - val_accuracy: 0.5897
# Epoch 23/50
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0621 - accuracy: 0.9806 - val_loss: 5.8028 - val_accuracy: 0.5897
# Epoch 24/50
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0136 - accuracy: 0.9871 - val_loss: 6.9937 - val_accuracy: 0.5897
# Epoch 25/50
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 8.4493 - val_accuracy: 0.5641
# Epoch 26/50
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 11.1969 - val_accuracy: 0.5385
# Epoch 27/50
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0149 - accuracy: 0.9935 - val_loss: 12.8022 - val_accuracy: 0.5385
# Epoch 28/50
# 5/5 [==============================] - 1s 227ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 11.3341 - val_accuracy: 0.5385
# Epoch 29/50
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 8.6031 - val_accuracy: 0.5385
# Epoch 30/50
# 5/5 [==============================] - 1s 224ms/step - loss: 1.5411e-04 - accuracy: 1.0000 - val_loss: 6.6231 - val_accuracy: 0.5897
# Epoch 31/50
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0094 - accuracy: 0.9935 - val_loss: 3.6032 - val_accuracy: 0.6667
# Epoch 32/50
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.8180 - val_accuracy: 0.7949
# Epoch 33/50
# 5/5 [==============================] - 1s 235ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.6654 - val_accuracy: 0.8462
# Epoch 34/50
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0069 - accuracy: 0.9935 - val_loss: 2.1987 - val_accuracy: 0.8205
# Epoch 35/50
# 5/5 [==============================] - 1s 246ms/step - loss: 1.6817e-04 - accuracy: 1.0000 - val_loss: 3.0901 - val_accuracy: 0.7179
# Epoch 36/50
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0670 - accuracy: 0.9806 - val_loss: 2.8540 - val_accuracy: 0.7436
# Epoch 37/50
# 5/5 [==============================] - 1s 223ms/step - loss: 0.1641 - accuracy: 0.9677 - val_loss: 9.8474 - val_accuracy: 0.5385
# Epoch 38/50
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0507 - accuracy: 0.9871 - val_loss: 11.5764 - val_accuracy: 0.5385
# Epoch 39/50
# 5/5 [==============================] - 1s 227ms/step - loss: 0.1638 - accuracy: 0.9548 - val_loss: 6.2533 - val_accuracy: 0.5385
# Epoch 40/50
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 4.2348 - val_accuracy: 0.6154
# Epoch 41/50
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 2.3677 - val_accuracy: 0.7436
# Epoch 42/50
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.3901 - val_accuracy: 0.8205
# Epoch 43/50
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0529 - accuracy: 0.9871 - val_loss: 1.7045 - val_accuracy: 0.8205
# Epoch 44/50
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.0100 - val_accuracy: 0.7692
# Epoch 45/50
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0533 - accuracy: 0.9935 - val_loss: 1.1935 - val_accuracy: 0.8718
# Epoch 46/50
# 5/5 [==============================] - 1s 240ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.1419 - val_accuracy: 0.8205
# Epoch 47/50
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0366 - accuracy: 0.9806 - val_loss: 1.2588 - val_accuracy: 0.8462
# Epoch 48/50
# 5/5 [==============================] - 1s 231ms/step - loss: 0.0388 - accuracy: 0.9871 - val_loss: 1.2137 - val_accuracy: 0.8974
# Epoch 49/50
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0065 - accuracy: 0.9935 - val_loss: 1.5642 - val_accuracy: 0.7949
# Epoch 50/50
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.9236 - val_accuracy: 0.7436
# 2/2 [==============================] - 2s 123ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#           NE       0.87      0.62      0.72        21
#           GL       0.67      0.89      0.76        18
#
#     accuracy                           0.74        39
#    macro avg       0.77      0.75      0.74        39
# weighted avg       0.77      0.74      0.74        39
